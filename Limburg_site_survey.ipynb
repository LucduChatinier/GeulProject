# %% [markdown]
# # Plot Limburg site survey

# %% [markdown]
# If you don't have the required packages installed yet, run the stuff below first.

# %%
# !conda install matplotlib cartopy
# !pip install git+https://github.com/TAHMO/OpenRiverCamLib.git
# Out:
# Collecting git+https://github.com/TAHMO/OpenRiverCamLib.git
#   Cloning https://github.com/TAHMO/OpenRiverCamLib.git to c:\users\luc du chatinier\appdata\local\temp\pip-req-build-hc3kzldy
#   Resolved https://github.com/TAHMO/OpenRiverCamLib.git to commit c79771ffeaedc76a142807472c20303a5070f776
# Requirement already satisfied: black in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (19.10b0)
# Requirement already satisfied: numpy in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (1.20.3)
# Requirement already satisfied: pip in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (21.2.4)
# Requirement already satisfied: scipy in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (1.7.1)
# Requirement already satisfied: scikit-image in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (0.18.3)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.5.4.60-cp39-cp39-win_amd64.whl (35.0 MB)
# Collecting openpiv
#   Using cached OpenPIV-0.23.8-py3-none-any.whl (22.3 MB)
# Collecting geojson
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting pyproj
#   Using cached pyproj-3.3.0-cp39-cp39-win_amd64.whl (6.3 MB)
# Collecting geos
#   Using cached geos-0.2.3-py3-none-any.whl (400 kB)
# Requirement already satisfied: shapely in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (1.7.1)
# Collecting rasterio
#   Using cached rasterio-1.2.10.tar.gz (2.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.9.tar.gz (2.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.8.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.7.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Running command git clone -q https://github.com/TAHMO/OpenRiverCamLib.git 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-req-build-hc3kzldy'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmp9dgrbcuf'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_6caf81a607ba47a4840f7ea78d36acce
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/44/5e/9f19e1e6fe980b59d8da8809f2e8f81eb7f0322c71914f077edcbcd9a110/rasterio-1.2.10.tar.gz#sha256=6062456047ba6494fe18bd0da98a383b6fad5306b16cd52a22e76c59172a2b5f (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmp9dgrbcuf' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpi019lmuw'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_a3b3f6e1b8e840bdb24affef5e5bfef9
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1f/70/4e7a789f4988955e4c381de80923e184f912683bbe6fc4a3a00c91efdf59/rasterio-1.2.9.tar.gz#sha256=012a4964d8db365be4fae0af9cbeba00e683e5904d5031e8ba42ccb6040cc887 (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpi019lmuw' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpdzop92qc'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_57deae567c8c4b9bb6a8e2087b22f8be
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5a/64/91fcf8482d5c380b68b4f69d5b0c75785db038b6923481b8e53234cf826f/rasterio-1.2.8.tar.gz#sha256=8196b7a71fea3c1573dd48d9ab0e78955e1d26e81848cce318c4930bd96782fe (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpdzop92qc' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmp_7m3icmv'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_26a648441eec46c4a474dadef095627e
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.6.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.5.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.4.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.3.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.2.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.1.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.2.0.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.8.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.7.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.6.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.5.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.4.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/bd/14/9dae549c8425c7f4d0819eb770875f813d46e97b3d75d5bbaeed22630f6a/rasterio-1.2.7.tar.gz#sha256=f97d688fd8bdf02a2d3c79fded6ba7409a62564fa59ddb43f8069c1b2610ee4f (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmp_7m3icmv' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpe7q7k0z8'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_fe38a61b19534171bb54dfb95fc8f2d7
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/d6/61/f083df6539a3ad5ddb480dd5551d55039b9f59948c68415a9737ea62081a/rasterio-1.2.6.tar.gz#sha256=24975b97fe2fc3fd282d59640baab19de431448e1b23be6b85b68fecc1362f88 (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpe7q7k0z8' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmptw_mr2z3'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_62bd3bc4ed894a67a2bf49f852ac4550
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/a3/2f30c89323826cba9344b55d3355df16695dff14aa312dbddb8050bb571f/rasterio-1.2.5.tar.gz#sha256=dbf85c2c3dbdc5000cb0afc24bd7625ff696bd8698661fed23d115164333d80f (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmptw_mr2z3' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpbqsfmjmp'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_3430c42813b64a11a7bbfd0228ebb211
#   Complete output (2 lines):
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/64/22/a8a0d384147fcbb2ecdea0a05d7d178e8692c62659fe733bd4b3966e6e95/rasterio-1.2.4.tar.gz#sha256=31248c5ddc8f138f73b166dd93384aa72d11abd0dc27dca90a190276c7976aa3 (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpbqsfmjmp' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tmpgj3ezqvr'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_fe55a62a33864b9a826480a500fcf8aa
#   Complete output (2 lines):

# %% [markdown]
# Import the necessary packages

# %%
# %matplotlib inline
import OpenRiverCam as orc
import matplotlib.pyplot as plt
import cv2
# Out:
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.3.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.2.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.1.tar.gz (2.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.1.0.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.0.28.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.0.27.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.0.26.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.0.25.tar.gz (2.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Using cached rasterio-1.0.24.tar.gz (1.9 MB)
#   Using cached rasterio-1.0.23.tar.gz (1.9 MB)
#   Using cached rasterio-1.0.22.tar.gz (1.9 MB)
#   Using cached rasterio-1.0.21.tar.gz (1.9 MB)
#   Using cached rasterio-1.0.20.tar.gz (1.9 MB)
#   Using cached rasterio-1.0.18.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.17.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.16.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.15.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.14.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.13.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.12.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.11.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.10.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.9.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.8.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.7.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.6.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.5.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.4.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.3.post1.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.3.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.2.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.1.tar.gz (1.8 MB)
#   Using cached rasterio-1.0.0.tar.gz (1.8 MB)
#   Using cached rasterio-0.36.0.tar.gz (1.2 MB)
# Requirement already satisfied: matplotlib in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (3.4.3)
# Collecting descartes
#   Using cached descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Collecting netCDF4
#   Using cached netCDF4-1.5.8-cp39-cp39-win_amd64.whl (3.0 MB)
# Requirement already satisfied: xarray in c:\users\luc du chatinier\anaconda3\lib\site-packages (from OpenRiverCam==0.1.dev65+gc79771f) (0.20.1)
# Requirement already satisfied: click>=6.5 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from black->OpenRiverCam==0.1.dev65+gc79771f) (8.0.3)
# Requirement already satisfied: attrs>=18.1.0 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from black->OpenRiverCam==0.1.dev65+gc79771f) (21.2.0)
# Requirement already satisfied: toml>=0.9.4 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from black->OpenRiverCam==0.1.dev65+gc79771f) (0.10.2)
# Requirement already satisfied: regex in c:\users\luc du chatinier\anaconda3\lib\site-packages (from black->OpenRiverCam==0.1.dev65+gc79771f) (2021.8.3)
# Requirement already satisfied: appdirs in c:\users\luc du chatinier\anaconda3\lib\site-packages (from black->OpenRiverCam==0.1.dev65+gc79771f) (1.4.4)
# Requirement already satisfied: typed-ast>=1.4.0 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from black->OpenRiverCam==0.1.dev65+gc79771f) (1.4.3)
# Requirement already satisfied: pathspec<1,>=0.6 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from black->OpenRiverCam==0.1.dev65+gc79771f) (0.7.0)
# Requirement already satisfied: colorama in c:\users\luc du chatinier\anaconda3\lib\site-packages (from click>=6.5->black->OpenRiverCam==0.1.dev65+gc79771f) (0.4.4)
# Requirement already satisfied: lxml in c:\users\luc du chatinier\anaconda3\lib\site-packages (from geos->OpenRiverCam==0.1.dev65+gc79771f) (4.6.3)
# Requirement already satisfied: flask in c:\users\luc du chatinier\anaconda3\lib\site-packages (from geos->OpenRiverCam==0.1.dev65+gc79771f) (1.1.2)
# Requirement already satisfied: pillow in c:\users\luc du chatinier\anaconda3\lib\site-packages (from geos->OpenRiverCam==0.1.dev65+gc79771f) (8.4.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from flask->geos->OpenRiverCam==0.1.dev65+gc79771f) (2.0.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from flask->geos->OpenRiverCam==0.1.dev65+gc79771f) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from flask->geos->OpenRiverCam==0.1.dev65+gc79771f) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->geos->OpenRiverCam==0.1.dev65+gc79771f) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from matplotlib->OpenRiverCam==0.1.dev65+gc79771f) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from matplotlib->OpenRiverCam==0.1.dev65+gc79771f) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from matplotlib->OpenRiverCam==0.1.dev65+gc79771f) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from matplotlib->OpenRiverCam==0.1.dev65+gc79771f) (0.10.0)
# Requirement already satisfied: six in c:\users\luc du chatinier\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->OpenRiverCam==0.1.dev65+gc79771f) (1.16.0)
# Requirement already satisfied: cftime in c:\users\luc du chatinier\anaconda3\lib\site-packages (from netCDF4->OpenRiverCam==0.1.dev65+gc79771f) (1.5.1.1)
# Requirement already satisfied: watermark in c:\users\luc du chatinier\anaconda3\lib\site-packages (from openpiv->OpenRiverCam==0.1.dev65+gc79771f) (2.2.0)
# Requirement already satisfied: GitPython in c:\users\luc du chatinier\anaconda3\lib\site-packages (from openpiv->OpenRiverCam==0.1.dev65+gc79771f) (3.1.24)
# Requirement already satisfied: imageio in c:\users\luc du chatinier\anaconda3\lib\site-packages (from openpiv->OpenRiverCam==0.1.dev65+gc79771f) (2.9.0)
# Requirement already satisfied: pytest in c:\users\luc du chatinier\anaconda3\lib\site-packages (from openpiv->OpenRiverCam==0.1.dev65+gc79771f) (6.2.4)
# Requirement already satisfied: natsort in c:\users\luc du chatinier\anaconda3\lib\site-packages (from openpiv->OpenRiverCam==0.1.dev65+gc79771f) (8.0.0)
# Requirement already satisfied: tqdm in c:\users\luc du chatinier\anaconda3\lib\site-packages (from openpiv->OpenRiverCam==0.1.dev65+gc79771f) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from GitPython->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (3.10.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from GitPython->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (5.0.0)
# Requirement already satisfied: certifi in c:\users\luc du chatinier\anaconda3\lib\site-packages (from pyproj->OpenRiverCam==0.1.dev65+gc79771f) (2021.10.8)
# Requirement already satisfied: iniconfig in c:\users\luc du chatinier\anaconda3\lib\site-packages (from pytest->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (1.1.1)
# Requirement already satisfied: packaging in c:\users\luc du chatinier\anaconda3\lib\site-packages (from pytest->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (21.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from pytest->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from pytest->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (1.10.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from pytest->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (1.4.0)
# Requirement already satisfied: affine in c:\users\luc du chatinier\anaconda3\lib\site-packages (from rasterio->OpenRiverCam==0.1.dev65+gc79771f) (2.3.0)
# Requirement already satisfied: cligj in c:\users\luc du chatinier\anaconda3\lib\site-packages (from rasterio->OpenRiverCam==0.1.dev65+gc79771f) (0.7.2)
# Requirement already satisfied: snuggs in c:\users\luc du chatinier\anaconda3\lib\site-packages (from rasterio->OpenRiverCam==0.1.dev65+gc79771f) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\luc du chatinier\anaconda3\lib\site-packages (from rasterio->OpenRiverCam==0.1.dev65+gc79771f) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from scikit-image->OpenRiverCam==0.1.dev65+gc79771f) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from scikit-image->OpenRiverCam==0.1.dev65+gc79771f) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from scikit-image->OpenRiverCam==0.1.dev65+gc79771f) (1.1.1)
# Requirement already satisfied: ipython in c:\users\luc du chatinier\anaconda3\lib\site-packages (from watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (7.29.0)
# Requirement already satisfied: pickleshare in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (0.1.2)
# Requirement already satisfied: pygments in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (58.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (0.18.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (5.1.0)
# Requirement already satisfied: backcall in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (0.2.0)
# Requirement already satisfied: decorator in c:\users\luc du chatinier\anaconda3\lib\site-packages (from ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from jedi>=0.16->ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\luc du chatinier\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark->openpiv->OpenRiverCam==0.1.dev65+gc79771f) (0.2.5)
# Requirement already satisfied: pandas>=1.1 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from xarray->OpenRiverCam==0.1.dev65+gc79771f) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\luc du chatinier\anaconda3\lib\site-packages (from pandas>=1.1->xarray->OpenRiverCam==0.1.dev65+gc79771f) (2021.3)
# Building wheels for collected packages: OpenRiverCam, rasterio
#   Building wheel for OpenRiverCam (setup.py): started
#   Building wheel for OpenRiverCam (setup.py): finished with status 'done'
#   Created wheel for OpenRiverCam: filename=OpenRiverCam-0.1.dev65+gc79771f-py3-none-any.whl size=30244 sha256=0799070b66768866b2e68d73e682c655325adb74526766ded121f922b31ddca5
#   Stored in directory: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-ephem-wheel-cache-qty9szia\wheels\bc\72\60\d7518f35546d1d24a1573ea0b6705ac722ed71c68e133fb378
#   Building wheel for rasterio (setup.py): started
#   Building wheel for rasterio (setup.py): finished with status 'error'
#   Running setup.py clean for rasterio
# Successfully built OpenRiverCam
# Failed to build rasterio
# Installing collected packages: rasterio, pyproj, openpiv, opencv-python-headless, netCDF4, geos, geojson, descartes, OpenRiverCam
#     Running setup.py install for rasterio: started
#     Running setup.py install for rasterio: finished with status 'error'
#   INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#   ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/97/85/3591f1b04fc9e9038aff7d6c5ddc816e8a7c0c8362f69b70ed6455ebcebd/rasterio-1.2.3.tar.gz#sha256=d8c345e01052b70ac3bbbe100c83def813c0ab19f7412c2c98e553d03720c1c5 (from https://pypi.org/simple/rasterio/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' 'C:\Users\Luc du Chatinier\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' get_requires_for_build_wheel 'C:\Users\LUCDUC~1\AppData\Local\Temp\tm
(from https://pypi.org/simple/rasterio/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_8046a6083f64499cb9101298672755f5\\setup.py'"'"'; __file__='"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_8046a6083f64499cb9101298672755f5\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-pip-egg-info-04ndtz9d'
#          cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_8046a6083f64499cb9101298672755f5\
#     Complete output (2 lines):
#     INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#     ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/75/88/1abc8a5128a66790d7e99ec3a6139d41ffd8f4fb0471218cfa3ce4e5ce4b/rasterio-1.0.20.tar.gz#sha256=820799cfd650d1518b52da9058a89a8d5452743d7593f3a57eab267b6a63b341 (from https://pypi.org/simple/rasterio/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_7a38c9a2768043aeb0fc3ce1caa82145\\setup.py'"'"'; __file__='"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_7a38c9a2768043aeb0fc3ce1caa82145\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-pip-egg-info-y9h5gst5'
#          cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_7a38c9a2768043aeb0fc3ce1caa82145\
#     Complete output (2 lines):
#     INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#     ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4e/79/b3e2d1783cde76d31eb87fa859eadf6855743d18c52942fbaa5f638e98a9/rasterio-1.0.18.tar.gz#sha256=02eabc24a2e1e323ebda385c608183a66ab56e46ff2077ac2aecd0f6ac3c3ea5 (from https://pypi.org/simple/rasterio/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
# ...
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7f/43/fb81ba30ddd3ba7cc6d381f4af35504cfd7ad7f1d46041850d03fc626c6a/rasterio-1.0.2.tar.gz#sha256=335eced9009852ce13517a88d4e05427c3fbda5f865e902e678612e2ab63b590 (from https://pypi.org/simple/rasterio/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_7cbee7695f254de4a89690954db3be7b\\setup.py'"'"'; __file__='"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_7cbee7695f254de4a89690954db3be7b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-pip-egg-info-btk58pni'
#          cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_7cbee7695f254de4a89690954db3be7b\
#     Complete output (2 lines):
#     INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#     ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ef/e2/eea3c9fd760b2fd3c68152e287e18698a11997ca265bbcbde999c13f1521/rasterio-1.0.1.tar.gz#sha256=b96be3e541f9f7b672eaa7b41bbe68216b5dea3dc7bcd96ef00db3c2a9553b15 (from https://pypi.org/simple/rasterio/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_8017247a533a4431b05878794de69417\\setup.py'"'"'; __file__='"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_8017247a533a4431b05878794de69417\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-pip-egg-info-ini0vbzs'
#          cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_8017247a533a4431b05878794de69417\
#     Complete output (2 lines):
#     INFO:root:Building on Windows requires extra options to setup.py to locate needed GDAL files. More information is available in the README.
#     ERROR: A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/33/22/ad2ea27c9829582ab5280f35cc61e424970ce0add34e258c9e171a62cb73/rasterio-1.0.0.tar.gz#sha256=6f2e90f2b740d727b36e39550e2a949d52551717812f9b4748f9bc351d666274 (from https://pypi.org/simple/rasterio/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'De externe host heeft een verbinding verbroken', None, 10054, None))': /simple/descartes/
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\\setup.py'"'"'; __file__='"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-wheel-3mhk336p'
#        cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\
#   Complete output (65 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\compat.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\coords.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\crs.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\dtypes.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\enums.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\env.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\errors.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\features.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\fill.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\mask.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\merge.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\plot.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\profiles.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\sample.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\tool.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\transform.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\vfs.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\warp.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\windows.py -> build\lib.win-amd64-3.9\rasterio
#   copying .\rasterio\__init__.py -> build\lib.win-amd64-3.9\rasterio
#   creating build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\bounds.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\calc.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\clip.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\convert.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\edit_info.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\env.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\helpers.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\info.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\insp.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\main.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\mask.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\merge.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\options.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\overview.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\rasterize.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\sample.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\shapes.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\stack.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\transform.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\warp.py -> build\lib.win-amd64-3.9\rasterio\rio
#   copying .\rasterio\rio\__init__.py -> build\lib.win-amd64-3.9\rasterio\rio
#   creating build\lib.win-amd64-3.9\rasterio\tools
#   copying .\rasterio\tools\mask.py -> build\lib.win-amd64-3.9\rasterio\tools
#   copying .\rasterio\tools\merge.py -> build\lib.win-amd64-3.9\rasterio\tools
#   copying .\rasterio\tools\__init__.py -> build\lib.win-amd64-3.9\rasterio\tools
#   running egg_info
#   writing rasterio.egg-info\PKG-INFO
#   writing dependency_links to rasterio.egg-info\dependency_links.txt
#   writing entry points to rasterio.egg-info\entry_points.txt
#   writing requirements to rasterio.egg-info\requires.txt
#   writing top-level names to rasterio.egg-info\top_level.txt
#   reading manifest file 'rasterio.egg-info\SOURCES.txt'
#   adding license file 'LICENSE.txt'
#   adding license file 'AUTHORS.txt'
#   writing manifest file 'rasterio.egg-info\SOURCES.txt'
#   running build_ext
#   building 'rasterio._base' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for rasterio
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\\setup.py'"'"'; __file__='"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-record-2ygu8ejr\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Luc du Chatinier\anaconda3\Include\rasterio'
#          cwd: C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-install-igilexcc\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\
#     Complete output (65 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\compat.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\coords.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\crs.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\dtypes.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\enums.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\env.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\errors.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\features.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\fill.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\mask.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\merge.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\plot.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\profiles.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\sample.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\tool.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\transform.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\vfs.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\warp.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\windows.py -> build\lib.win-amd64-3.9\rasterio
#     copying .\rasterio\__init__.py -> build\lib.win-amd64-3.9\rasterio
#     creating build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\bounds.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\calc.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\clip.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\convert.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\edit_info.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\env.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\helpers.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\info.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\insp.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\main.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\mask.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\merge.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\options.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\overview.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\rasterize.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\sample.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\shapes.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\stack.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\transform.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\warp.py -> build\lib.win-amd64-3.9\rasterio\rio
#     copying .\rasterio\rio\__init__.py -> build\lib.win-amd64-3.9\rasterio\rio
#     creating build\lib.win-amd64-3.9\rasterio\tools
#     copying .\rasterio\tools\mask.py -> build\lib.win-amd64-3.9\rasterio\tools
#     copying .\rasterio\tools\merge.py -> build\lib.win-amd64-3.9\rasterio\tools
#     copying .\rasterio\tools\__init__.py -> build\lib.win-amd64-3.9\rasterio\tools
#     running egg_info
#     writing rasterio.egg-info\PKG-INFO
#     writing dependency_links to rasterio.egg-info\dependency_links.txt
#     writing entry points to rasterio.egg-info\entry_points.txt
#     writing requirements to rasterio.egg-info\requires.txt
#     writing top-level names to rasterio.egg-info\top_level.txt
#     reading manifest file 'rasterio.egg-info\SOURCES.txt'
#     adding license file 'LICENSE.txt'
#     adding license file 'AUTHORS.txt'
#     writing manifest file 'rasterio.egg-info\SOURCES.txt'
#     running build_ext
#     building 'rasterio._base' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\Luc du Chatinier\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\\setup.py'"'"'; __file__='"'"'C:\\Users\\Luc du Chatinier\\AppData\\Local\\Temp\\pip-install-igilexcc\\rasterio_a2bdcf55b7af4d32ab3a592350b04e01\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Luc du Chatinier\AppData\Local\Temp\pip-record-2ygu8ejr\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Luc du Chatinier\anaconda3\Include\rasterio' Check the logs for full command output.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\LUCDUC~1\AppData\Local\Temp/ipykernel_20308/960253253.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 import OpenRiverCam as orc
#       3 import matplotlib.pyplot as plt
#       4 import cv2
#
# ModuleNotFoundError: No module named 'OpenRiverCam'

# %% [markdown]
# Instead of having to type a very large amount of variables here, all information about the site is collected in a fiule called `example_data.py`. We import this below. You can inspect the file yourself in a IDE or text editor/viewer. All variables should be available after sourcing it.

# %%
from example_data import *
# check gcps
gcps

# %% [markdown]
# Above you can see the GCP information we need to reproject in a dictionary. You won't be needing this, but still cool to understand the process.
# * src: the points in a (lens corrected) single frame measured in cols, rows in the frame, where we know the geographical x, y, z coordinates
# * dst: the x, y geographical coordinates (in a local projection) of the same locations
# * z_0: the measured height (with GPS, referenced to a typical geographical datum) at those locations. All gcps are taken at the same height hence this is just one number
# * h_ref: the height of the water level as measured on the staff gauge. This is used so that we can refer back what water level in staff gauge, relates to water level in GPS coordinates.

# %% [markdown]
# # 3D map of collected data
# Below, a plot of the bathymetry is shown. The camera is positioned such that it looks at a slant angle to the cross-section. The cross section is measured until quite far bank inwards.

# %%
f = plt.figure(figsize=(16, 16))
ax = plt.axes(projection='3d')
coords = list(zip(*bathymetry["coords"]))
ax.scatter3D(*coords, c=coords[-1], cmap='rainbow', label="cross section")
ax.plot3D(
    (
        lensPosition[0],
        lensPosition[0]
    ), (
        lensPosition[1],
        lensPosition[1]
    ), (
        lensPosition[2],
        np.array(coords[-1]).min() # top of pole to the channel bottom coordinate

    ), color="b", linestyle="--", label="channel bottom - top pole"
)

ax.plot3D(
    (
        lensPosition[0],
        lensPosition[0]
    ), (
        lensPosition[1],
        lensPosition[1]
    ), (
        lensPosition[2],
        lensPosition[2] - 3. # lens pole is about 3 meters, we plot the pole height here

    ), color="b",  label="pole"
)

for n, gcp in enumerate(gcps["dst"]):
    if n ==3:
        ax.scatter3D(*gcp, gcps["z_0"], color="k", marker="s", label="marker")
    else:
        ax.scatter3D(*gcp, gcps["z_0"], color="k", marker="s")

ax.scatter3D(*lensPosition, cmap="Blues", label="camera")

ax.legend()
